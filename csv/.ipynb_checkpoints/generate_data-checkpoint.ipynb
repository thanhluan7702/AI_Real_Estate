# %%
import openai

api_key = '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'

# %%
def extract_entities(describe):
    
    prompt = describe + '''Dựa vào văn bản mô tả sản phẩm bất động sản ở trên, bạn hãy trích xuất cho tôi các thông tin theo 
            định dạng json wrapper sau với key là thuộc tính còn value là giá trị được trích xuất văn bản mô tả, với thuộc
            tính nào không có giá trị thì bạn không cần phải trả về: 
            {
            'giá': cụ thể giá,
            'địa chỉ': địa chỉ cụ thể,
            
            'diện tích' : diện tích của bất động sản, 
            'chiều dài bds': chiều dài cụ thể của bất động sản,
            'chiều rộng bds': chiều rộng hoặc ngang của bất động sản,
            
            'hướng nhà': hướng nhà cụ thể,
            'hình dáng nhà': ví dụ như nở hậu hay chữ L,
            
            'view': view nhìn như thế nào,
            'vị trí' : mặt tiền hay hẻm/ kiệt, 
            'địa điểm' : vị trí của bất động sản ở ngoại ô hay trung tâm thành phố,
            'vỉa hè' : nếu có thì bao nhiêu,
            'dân cư' : đông đúc hay vắng vẻ, 
            'kinh doanh' : thuận tiện hay không thuận tiện,
            'khả năng thoát nước' : trích từ văn bản,
            'phong thủy' : phong thủy như thế nào,
            'tình trạng hiện tại': hiện tại hoặc quá khứ đang là nhà ở hay kinh doanh dịch vụ gì,
            
            'nội thất': tình trạng nội thất cụ thể,
            'số phòng ngủ': cụ thể số phòng,
            'số toilet': cụ thể số phòng,
            'phòng bếp': có hay không,
            'phòng khác': ví dụ như phòng ăn, phòng khách, phòng tập gym,
            'số tầng': số tầng cụ thể đang ở,
            'tổng số tầng': cụ thể tổng số tầng, 
            'khu vực để xe' : có hay không,
            'sân thượng/ ban công' : có hay không,
            'sân vườn': có hay không,
            'cách mặt đường': cụ thể khoảng cách tới mặt đường,
            'cổng/ rào': có hay không,
            'tiện ích khác': ví dụ như hồ bơi, ao cá, vườn rau, 
            'số cửa chính': cụ thể số cửa chính,
            'số cửa sổ': cụ thể số cửa,
            
            'pháp lý': tình trạng pháp lý,
            
            'siêu thị': cụ thể khoảng cách,
            'bệnh viện':  cụ thể khoảng cách,
            'trường học':  cụ thể khoảng cách,
            'chợ':  cụ thể khoảng cách,
            'khu vui chơi': cụ thể khoảng cách,
            'trung tâm thành phố':  cụ thể khoảng cách,
            'biển':  cụ thể khoảng cách,
            'công viên': cụ thể khoảng cách,
            
            'tên': tên người đăng,
            'liên hệ': số điện thoại người đăng
            }
            '''
            
    response = openai.Completion.create(
        engine = 'gpt-3.5-turbo-instruct',
        prompt=prompt,
        max_tokens=800, 
        temperature= 0.7,
        api_key=api_key
    )

    new_sentence = response.choices[0].text.strip()
    return new_sentence

# %%
describe = '''+ Cần bán nhà 4 tầng đường An Thượng, nhà mới thiết kế hiện đại. 
            - Dt đất : 95m2, đường 5m5 lề 3m
            - Vị trí gần tất cả tiện ích, gần các trường cấp 1-2-3, cách biển 50m, đặt biệt nằm ngay trung tâm phố tây An 
            Thượng dân cư đông đúc, an ninh đảm bảo
            - có hồ cá nhỏ
            - mùa mưa không bị ngập
            - Công năng: gồm 4 phòng ngủ, 5wc , phòng ngủ nào cũng có view và cữa sổ thoáng mát
            - Hiện đang cho thuê làm Spa 25 triệu/ tháng. Hợp đồng còn 4 năm.
            - Chủ là kiến trúc sư nổi tiếng, xây dựng ngôi nhà tâm huyết và rất kiên cố, toàn bộ nội thất từ 
            Nội Thất TOTO cao cấp, sàn nhà làm bằng đá tự nhiên và gỗ dày 1,8cm. Nói chung nội thất nhà rất đỉnh và xịn xò.
            📕 sổ đỏ vương vắng - thương lượng hợp lý'''
            
print(extract_entities(describe))
# Out:
# {
#     'giá': 25 triệu/tháng,
#     'địa chỉ': đường An Thượng,
#
#     'diện tích' : 95m2,
#     'chiều dài bds': không có,
#     'chiều rộng bds': không có,
#
#     'hướng nhà': không có,
#     'hình dáng nhà': không có,
#
#     'view': view nhìn ra hồ cá nhỏ,
#     'vị trí' : trung tâm phố tây An Thượng,
#     'địa điểm' : không có,
#     'vỉa hè' : 3m,
#     'dân cư' : đông đúc,
#     'kinh doanh' : thuận tiện,
#     'khả năng thoát nước' : không bị ngập,
#     'phong thủy' : không có,
#     'tình trạng hiện tại': đang cho thuê làm Spa 25 triệu/ tháng,
#
#     'nội thất': Nội Thất TOTO cao cấp, sàn nhà làm bằng đá tự nhiên và gỗ dày 1,8cm,
#     'số phòng ngủ': 4,
#     'số toilet': 5,
#     'phòng bếp': có,
#     'phòng khác': không có,
#     'số tầng': 4,
#     'tổng số tầng': không có,
#     'khu vực để xe' : không có,
#     'sân thượng/ ban công' : không có,
#     'sân vườn': không có,
#     'cách mặt đường': 50m,
#     'cổng/ rào': không có,
# ...
